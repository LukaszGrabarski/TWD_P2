# %%
import pandas as pd
import numpy as np
import os, os.path
import pathlib
import json
import re
from functools import partial
from datetime import date
from statistics import mean
import collections
from sklearn.feature_extraction.text import CountVectorizer

# %%
# zbiorcza ramka do głownej analizy
merged_message = pd.DataFrame(
    {"file" : [],
    "participants" : [],
     "mean_my_res_time" : [],
     "mean_other_res_time" :[],
    "my_messages" : [],
     "all_messages" : []
    },
    )

merged_common_words = pd.DataFrame(
    {"word" : [],
    "count" : [],
     "file" : [],
    },
    )

merged_time = pd.DataFrame(
    {"date" : [],
     "file" : []
    },
    )

# %%
# aby emotki działały
fix_mojibake_escapes = partial(
        re.compile(rb'\\u00([\da-f]{2})').sub,
        lambda m: bytes.fromhex(m[1].decode()),
    )

# %%
#stopwords = set(line.strip() for line in open('stopwords.txt', 'utf8'))
stopwords = set(line.strip() for line in open('stopwords.txt', encoding='utf8'))

# %%
        me = "Łukasz Grabarski"

# %%
    #idziemy po wzystkich jsonach w folderze
for file in pathlib.Path('inbox').glob('**/*.json'):
        #file = "inbox/agnieszkagrabarska_ubdmm4mxea/message_1.json"
        #rozmowa = "Agnieszka Grabarska"
        rozmowa = os.path.basename(file.parent).split('_')[0]    

        #importujemy plik z działającymi polskimi znakami
        with open(file, 'rb') as binary_data:
            repaired = fix_mojibake_escapes(binary_data.read())
        data = json.loads(repaired)

        #normalna eksploracja danych
        df_participants = pd.DataFrame(data['participants'])
        df_messages = pd.DataFrame(data['messages'])
        df_messages['date'] = pd.to_datetime(df_messages.timestamp_ms, unit = 'ms')

        participants = df_participants['name'].size
        mean_other_res_time = -1
        mean_my_res_time = -1
        my_messages = len(df_messages[df_messages.sender_name == me])
        all_messages = len(df_messages['sender_name'])
        title = data['title']

        #if len(df_messages['sender_name']) < 2:
            #continue
        #badamy czas odpowiedzi
        if participants == 2:
            senders = list(df_messages['sender_name'])
            times =  list(df_messages['timestamp_ms'])
            times.reverse()
            senders.reverse()
            response_time_my = list()
            response_time_other = list()
            iprev = 0

            for i in range(len(times)):
                if senders[i] != senders[iprev]:
                    if senders[i] == me:
                        response_time_my.append(times[i] - times[iprev])
                    else:
                        response_time_other.append(times[i] - times[iprev])

                iprev = i

            if len(response_time_my) > 2:          
                mean_my_res_time = round(mean(response_time_my))
            if len(response_time_other) > 2:          
                mean_other_res_time = round(mean(response_time_other))

        # najczęstrze słowa
        #print(df_messages.query('sender_name == @me'))
        
        print(title)
        if 'content' not in df_messages:
            continue
        
        content = list(df_messages.query('sender_name == @me')['content'])
        content = ' '.join(map(str, content))
        wordcount = {}

        for word in content.lower().split():
            word = word.replace(".","")
            word = word.replace(",","")
            word = word.replace("nan","")
            word = word.replace("-"," ")
            word = word.replace(":","")
            word = word.replace("\"","")
            word = word.replace("!","")
            word = word.replace("*","")
            if word not in stopwords:
                if word not in wordcount:
                    wordcount[word] = 1
                else:
                    wordcount[word] += 1

        n_print = 10
        word_counter = collections.Counter(wordcount)
        
        if word_counter.get("") != None:
            word_counter.pop("")
        word_counter = (pd.DataFrame(list(word_counter.most_common())))
        word_counter['file'] = title
        word_counter.rename(columns = {0 : 'word', 1 : 'count'}, inplace = True)    

        #czas wysłania wiadomości

        messages_time = pd.DataFrame(df_messages.query('sender_name == @me')['date'])
        #messages_time.rename(columns = {0 : 'date'}, inplace = True)
        messages_time['file'] = title

       # print(messages_time)


       # print(word_counter.most_common(n_print))

       # for word, count in word_counter.most_common(n_print):
        #    print(word, ": ", count)


        #mergujemy z główną ramką
        df_to_merge = pd.DataFrame({"file" : title,
                                    "participants" : participants,
                                    "mean_my_res_time" : mean_my_res_time,
                                    "mean_other_res_time" : mean_other_res_time,
                                    "my_messages" : my_messages,
                                    "all_messages" : all_messages},
                                  index=[1])

        #print(df_to_merge)
        merged_message = pd.concat([merged_message, df_to_merge])
        merged_common_words = pd.concat([merged_common_words, word_counter])
        merged_time = pd.concat([merged_time, messages_time])
# Out:
# 10.11
# 18 Łukasza🎉
# 18
# 19.03 🥳
# 20 urodzinki tymka
# 3B Chłopacy
# 3B eWychowawcza
# 3D
# 3D
# 4min4life <3
# 8 LO MINECRAFT IP: grzybek.bymarcin.com:2137
# 8melowa Grupa niePoprawnych Politycznie
# 8melo
# 9 lutego ✨
# Adam Adam
# Adam Ciborek
# Adam Dęby
# Adam, Jakub, Kacper i 11 innych użytkowników
# Adam Kąkolewski
# Adam Krystek
# Adam Naumiec
# Adam Przemysław Chojecki
# Adrian Cieśla
# Adrian Dolecki
# Adrian Gołębiowski
# Adrian Kaźmierczuk
# Adrian Zaręba
# Aga Mańke
# Aga Mańke
# Aga Mańke
# Aga Mańke
# Aga Mańke
# Aga Mańke
# Aga Mańke
# Agata Andrzejczak
# Agata Boruta
# Agata Chałupniczak
# Agata Gerl
# Agata i Zosia
# Agata Kaczmarek
# Agata Makarewicz
# Agata, Szy, Zosia i 3 innych użytkowników
# Agnieszka Balcerowiak
# Agnieszka Dziadek
# Agnieszka Grabarska
# Agnieszka Kaczmarek
# Agnieszka Kaczmarek
# Agnieszka Zwolińska
# AJR
# AKCJA: WARSZAFKA
# Alan Kirpa
# Ala Röhl
# Ala Tacakiewicz
# Alek Malinowski
# Aleksander Mieszała
# Aleksandra Drozd
# Aleksandra Dworzak
# Aleksandra Grabarska
# Aleksandra i Magdalena
# Aleksandra Konieczka
# Aleksandra Kulczycka
# Aleksandra Ortyl
# Aleksandra Paździorek
# Aleksandra Pela
# Aleksandra Piotrowicz
# Aleksandra Spychała
# Aleksandra Sroka
# Aleks Kapich
# Alicja Charuza
# Alicja Grześków
# Alicja Nowicka
# Amelia Janc
# Amelia Łakoma
# Amelia Maćkiewicz
# Amelia Spirra
# Andrii Voznesenskyi
# Andrzej Łuczak
# Andrzej Mostaller
# Andżelika Kotas
# Angelika Miszkurka
# Ania, Kacper i Aga
# Ania Kuska
# Ania Linka
# Ania Majka
# Ania Mąkowska
# Ania Stachowiak
# Ania Wawdysz
# Ania, Zuza, Maja i 6 innych użytkowników
# Aniela Walicka
# Ankieta PP
# Anna Katarzyna Dróżdż
# Anna Klein
# Antoni Klimaszyk
# Arleta Posadzińska
# Artur Wypych
# Asia Barteczka
# Asia, Basia i Joanna
# Asia Spychała
# ATAS Wyjazdy młodzieżowe
# AtoMiNIówki🍑
# Balik ✌️❤️🎉
# bandita
# Bartek Marlicki
# Bartłomiej Woroch
# Бартош Бернацки
# Bartosz Barszcz
# Bartosz Kaczorowski
# Bartosz Merda
# Bartosz Wojciechowski
# Basia Grec
# Basia Janicka
# Basia Jurzysta
# Белосток
# Białystok
# Bieg Motyli 🦋
# Bierzmowanie
# Biznesplan PP
# #Bluzy2020
# bluzy (i nie tylko 😉)
# Bluzy
# Bluzy
# BÓBR(Z)
# Bogna Frykowska
# Bractwo pustego kieliszka
# Cezary Botta
# Cezary Pazura - profil oficjalny
# Chillzone Ósemka
# Chillzonowi Artyści
# Chryzantemy złociste💐
#
# Coca-Cola
# Collegium Da Vinci
# Człowiek Przedsiębiorczy
# Dagna Kończak
# Dawid Michałek
# Dawid Poławski
# Dawid Szymański
# Dobrochna Smółka
# Dojazd do Michała
# Dominika Encminger
# Dominika Grudzień
# Dominika Iwanicka
# Dominika Martenka
# Dominika Niespodziana
# Dominika Nowak
# Dominika Oleszczak-karki
# Dominika Ratka
# Dominika Szmit
# Dominika, Zosia i Sandra
# Dominik Borzyczkowski
# Dominik Jaworski
# Dominik Łukowski
# Dorota Hływa
# Dorota Malińska-Janaś
# Dorota Obrowska
# Dorota Posadzińska
# Działencja
# Dzień kobiet 2018
# ekipa kino
# Ekipa Polonez🎉
# Eliza Anna
# Emigmat
# Emilia Oleszczyk
# Emilia Pelc
# Emil Maćkowiak
# Emma Leveilley
# empik
#
# Energy siłownia-fitness
# EverWing
# Ewa Jabłońska
# Ewa Ziętek
# EYE 2020
# Facebook user, Zosia, Paulina i 2 innych użytkowników
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Facebook user
# Fanta
# Felicja Warno
# Filip Podalak
# Filip Rabiega
# Filip Suliński
# Filip Surmacz
# #film o dobrych ludziach
# Filtrowa 💃🕺
# fizyka
# Florentyna Dąbkowska
# Franciszek Kurowski
# Franciszek Szkudelski
# Franek Szczepaniak
# fYOUture
# Gabriela Krzyżańska
# Gerard Pryncypałki
# Giovita Kalinowska
# Gołębnik
# Grupa dla Kacpra do koncertowania
# Grzegorz Świąder
# Halloweenowe Podchody
# Hania Pocik
# Hanka Grubich
# Hanna Kozera
# Hanna Kukawska
# Hanna Szafrańska
# Helena Karolczak
# Hinduizm (22.01.2k20)
# Hirek Norkiewicz
# Horla Horlaiz Dc II
# Hubert Baraniak
# Idziemy Coś Zjeść
# Iga Zamroczyńska
# Igor Staręga
# IiAD Gang + przyjaciele
# Iluzjonista Y
# Imprezowa 1B🥃🍾🥂🍹🍸
# InPost - Paczkomat, Kurier
# Inwazja Młodzieży na Urząd Marszałkowski
# Inżynieria i Analiza Danych
#
# isi
# Italiano
# Iwona Lisiecka
# Iwona Wendt
# Izabela Filas
# Jacek Fischer
# Jacek Wiśniewski
# Jagoda Janowska
# Jagoda Róża Moniak
# Jakub Ciężki
# Jakub Grzywaczewski
# Jakub Jung
# Jakub Kaźmierczak
# Jakub Kolasiński
# Jakub Kotowski
# Jakub Lange
# Jakub Lewandowski
# Jakub Marciniak
# Jakub Marcinkowski
# Jakub, Michał i Grzegorz
# Jakub Monterial
# Jakub Patera
# Jakub Rejdych
# Jakub Torłop
# Jakub Traczyk
# Jan Dudek
# Janek Pogłód
# Jan Konieczko
# Jan Majchrzak
# Jan Malewski
# Jan Olszewski
# Jarosław Goldberg
# Jędrzej Broniarek
# Jędrzej Konieczny
# Jędrzej Kozak
# jestesmy dorosli
# Joanna Barteczka
# Joanna Chudy-Noska
# Joanna Jędrzejak
# Joanna Magdziarz
# Joanna Mąkosa
# Joanna Podgórska
# JOGA BONITO
# Józef Owecki
# Julia Biegańska
# Julia Boruta
# Julia Czyżewska
# Julia Frankiewicz
# Julia Frankiewicz
# Julia Karwowska
# Julia Krawczyk
# Julia Mizera
# Julianna Wegner
# Julia Ordecka
# Julia Staniszewska
# Julia Walczak
# Julia Wojciechowska
# Julia Żurek
# Julka Marecka
# Justyna Ratka
# Juwenalia Piątek 🍻🎶
# Kacper Alexander
# Kacper Banachowicz
# Kacper Klepczyński
# Kacper Kowalczyk
# Kacper, Martyna, Amelia i 4 innych użytkowników
# Kacper Nowicki
# Kacper Ogdowski
# Kacper Paluszkiewicz
# Kacper Wnęk
# Kaftanik Dla Wszystkich
# Kajetan Oleśków
# Kajetan Szamotula
# Kalesony
# Kamila Kozera
# Kamila Maciejewska
# Kamil Kisiel
# Kamil Korpik
# Kamil Krawczyk
# Kamil Szymczak
# Kamil Wojciechowski
# Kandydaci Do Samorządu󾌰
# Kandydaci do SzRU
# Kara Rodziny 👌
# Karola Boral
# Karol Gązwa
# Karolina Dębicka
# Karolina Domańska
# Karol Nowicki
# Kartki z kalendarzy i gotowe prezenty
# Kasia Buszka
# Kasia Józefiak
# Kasia Nowak
# Katarzyna Golla
# Katarzyna Grzegorek
# Katarzyna Jasińska
# Katarzyna Mielniczuk
# Katarzyna Pawłowska
# Katyń
# KAWA
# Kawiarenka
# Kinga Bogusławska
# Kinga Jot
# Kinga Kledzik
# Kinga Matuszewska
# Kinga Stępniak
# Klaudia Kornatowska
# Klaudia Lenartowicz
# Klaudia Majek
# Klaudia Milachowska
# Klub Filmowo-Fotograficzny "Focus"
# Klub Morsów Piła
# Klub Wzajemnej Adoracji <3
# Klub Wzajemnej Adoracji <3
# Konrad Górka
# Konrad Sidor
# Krasz Krasz
# Krreegle
# Krystyna Adamczyk
# Krzysztof Bartczak
# Krzysztof Goławski
# Krzysztof Kosz
# Krzysztof Kubiak
# Krzysztof Sawicki
# Krzysztof Wiśniecki
# Kuba Bachmatiuk
# Kuba Klawiter
# Kuba Klimek
# Kuba Kuchta
# Kuba Pituła
# Kuba Rymarski
# KURNIK
# Lecimy.
# Ledsy
# Lena Woźniak
# Leonardo Vincii
# Lepsza Grupa Niemiecki
# Lidia Wysocka
# Liliana Czarnecka
# Lubelska
# Ludo Club by Moonfrog
# Ludzie MINImalnej Kultury
# Łukasz Grabarski
# Łukasz Kałek
# Łukasz Lach
# Łukasz Lepianka
# Łukasz Maćkowiak
# Łukasz Röhl
# Łukasz Sioda
# Łukasz Sz
# Łukasz Wawrzyniak
# Łukasz Ziembikiewicz
#
# Maciej Borkowski
# Maciej Grabarski
# Maciej Łyskawiński
# Maciek Kułacz
# Magda Figurska
# Magdalena Grabarska
# Magdalena, Jake, Roger i 16 innych użytkowników
# Magdalena Jeczeń
# Maja i Aga
# Maja Kudlinska
# Maja Kurzawska
# Maksymilian Kozłowski
# Małgorzata Kornacka
# Małgorzata Rogalska
# Małgosia Misiak
# 🎨 Malujemy! dla Pani Hani
# Manufaktura Lodów Prawdziwych
# Marcelina Lenicka
# Marcel Matuszak
# Marcin Ignaszewski
# Marcin Okonek
# Marcin Pater
# Marcin Słupczyński
# Maria Margarete Reyes
# Maria Mata
# Maria Nowakowska
# Maria Siemieniak
# Marija Masha Regulska
# Marika Kopertowicz
# Marika, Zosia i Klaudia
# Mariola Bilejczyk
# Mariusz Dwużnik
# Marta Cieślak
# Marta Hała
# Marta Marciniak
# Marta Martenka-Jeszke
# Marta Mazanka
# Marta Mikołajczak
# Marta Piosik
# Marta Szuwarska
# Marta Trembowelska
# Marta Wajer
# Martyna Bartczak
# Martyna Długaszewicz
# Martyna Dobska
# Martyna Feferkuch
# Martyna Kuśmierz
# Martyna Majchrzak
# Martyna Michałek
# Martyna Rychlik
# Martyna Straszewska
# Mar Wyp
# Marysia Łopińska
# Masny Rafał
# Mateusz Antonik
# Mateusz Bil
# Mateusz Flis
# Mateusz i Mikołaj
# Mateusz Jasiński
# Mateusz Kubita
# Mateusz Madej
# Mateusz Nizwantowski
# Mateusz, Paulina, Nikodem i 2 innych użytkowników
# Mateusz, Paulina, Nikodem i Lena
# Mateusz Puchała
# Mateusz Radka
# Mateusz Sobolewski
# Mateusz Sobolewski
# Mateusz Spychała
# Mateusz Wiktorzak
# Mati Andryszak
# matma
# Matthew Stepczak
# MediaMarkt Polska POMOC
# MediaMarkt Polska
# Michaił Legczylin
# Michał, Artur, Oliwier i 7 innych użytkowników
# Michał Baran
# Michał Binda
# Michał Budzyński
# Michał Chęć
# Michalina Kozłowska
# Michalina Rewolińska
# Michał Marek
# Michał, Mateusz, Jakub i 3 innych użytkowników
# Michał Obrowski
# Michał Rajek
# Michał Ratajczak
# Michał Zmyślony
# Miejsko-Gminne Centrum Kultury w Kaczorach
# Mikołaj, Ania, Julia i 2 innych użytkowników
# Mikołaj Charchuta
# Mikołaj Dziewiatowski
# Mikołaj i Aga
# Mikołaj Majchrzak
# Mikołaj Miedziak
# Mikołaj Mróz
# Mikołaj Popek
# Mikołaj Szawerda
# Mikołaj Szawerda
# Mikołaj Szawerda
# Mikołaj Szawerda
# Mikołaj Szumlański
# Mikołaj Wieczorek
# Milionerzy TVN
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość Jest Piękna
# Miłość
# Miłosz Wiertel
# Mimka Halinka
# Mir Ban
# misja kebsik😎💞💕
# Misja projekt 😈
# MKA ✌️
# MKA ✌️
# MKA ✌️
# MKA ✌️
# MKA ✌️
# Mobzilla
# Monika Gruse-Chrzanowska
# Monika Ignaszewska
# MRMP IV Kadencja
# MRM po godzinach
# Nadia Kluz
# Najlepsi Z Najlepszych 󾌴󾬒󾬐
# Natalia Jankowska
# Natalia Kuchta
# Natalia Niedźwiedzka
# Natalia Safiejko
# Natalia Wieczorek
# Niedziela Wieczur Humor Gituwa
# Nie Głodowanie Razem
# Niemiecki 3B Grupa Mniej Zaawansowana
# NIE MÓWMY O TYMXD
# Niespodzianka dla Amelii
# Night Hunting
# Nikodem Dudek
# Nocki u Zosi 💖
# Norbert Posadzinski
# Notatki na Polski
# Obchody 10. rocznicy Libacji na skwerku
# Oborniki
# Oglądam "Wiadomości", bo nie stać mnie na dopalacze
# Okaryny
# Ola Grabarska
# Ola Kornel
# Ola Mozolewska
# Ola Novák
# Ola Wieczorek
# Olek Kornaga
# Olga Niedorys
# Olga Sobolewska
# Oliwia Szłapa
# Oliwia Urbaniak
# Oliwia Wika-Czarnowska
# Oliwier Adamczyk
# Oskar Turowicz
# Ostateczna Grupa Na Wyjazd W Karkonosze
# Otrzęsiny 🔥🔥
# Paco Reyes Morillo
# Pączki 💪🍩
# Patrycja Bethke
# Patrycja Kasprzak
# Patrycja Kozera
# Patrycja Lewandowska
# Patrycja Rogulska
# Patrycja Wasielewska
# Patrycja Wróbel
# Paulina Dąbrowska
# Paulina Kledzik
# Paulina Lisiecka
# Paulina Przybyłek
# Paulina Szak
# Paulina Wójcik
# Paweł Kamiński
# Paweł Kubiak
# paysafecard
# Piaskowska Julita
# pierwszaki
# Piotr Baranowski
# Piotrek Głowacki
# Piotr Górawski
# Piotr Iwaszkiewicz
# Piotr Jankiewicz
# Piotr Kosakowski
# Piotr Łuczak
# Piotr Martenka
# Piotr Sowiński
# Piotr Szczeszek
# Piotr Wieczorek
# Piotr Wysocki
# Piotr
# Piwo
# PKA IAD
# Plakat (?) XD
# Planszówki vol. ♾️
# płyta
# Podbijamy EYE
# Podgrupa ds. Grupy
# Pola Kierska
# Polny Bar Mleczny
# Poradnia Browarska - Danonki J5
# Pp
# Pracownia Renowacji Drewna
# prezent dla agi
# Prezent dla dziewiata
# Prezent dla Julci 💜
# prezent dla Lenki
# Prezent dla Martyny
# prezent dla tymka
# Projekt Dla Wiesi
# projekt fizyka
# Projekt Polski
# projekt z polskiego.
# Radosław Noska
# Rafał Pyzowski
# Rafał Teresiński
# Remigiusz Jakub Wierzgoń
# Renata Rólkiewicz
# Robert Makłowicz
# Rodzinka <3
# Rodzinne pogaduchy❤
# Roksana Ulfik
# Rolnicy Ósemki 🥔
# Rozmowni ludzie💕
# Roztańczeni💃🏻🕺🏻❤
# RP - płakanie
# Rrrr
#
# Samorząd Studentów SGH
# Samouczki fan club
# Sandra Górska
# Sandra Kowalska
# Schronisko Bukowina - Restauracja i Sklep
# Sebaastian Witt
# Sebastian Tritt
# Sebastian Trojan
# Socjal 2k22
# Somersby
# Spam WRS MiNI 2021
# Spam WRS MiNI 2022
# Spam WRS MiNI 2023
# 🇺🇸Spiskowe Teorie Majewskiej🇺🇸
# spotkanie w dniu 05.11 testujemy limitu auuuu
# Spotted: Budzyń i okolice
# Spotted: Chodzież
# Spotted: Piła i okolice
# Spotted: Wałcz i okolice
# Spotted: Złotów i okolice
# Spotted: Złotów
# SSH SSH
# Stanisław Białka
# Stanisław Wiśniewski
# Starostowie
# Start-up Society Poznań
# Studniówka
# Światła, Kamera, Akcja!
# Sylwia Cyran
# Sylwia Donal
# Szefostwo Na Wrzesień
# Szkolenie 4 Jeźdźców Apokalipsy
# Szkolenie Centralne SSPW 👾🤖
# Szkolenie Sobota
# Szkolna Rada Uczniowska w VIII LO w Poznaniu
# SzRU 2018/19
# SzRU 2019/20
# SzRU 2020/21 [OFFTOP]
# SzRU 2021/22
# Sztab Wyborczy❤
# Szy Cy
# Szymon Abramczyk
# Szymon Kin
# Szymon Kin
# Szymon Lach
# Szymon Tuz
# TEDxMickiewiczHighSchool
# Teksiciarze
# Tomasz i Zosia
# Tomasz Poprawski
# Tomasz Witkowski
# Tomasz, Zosia i Klaudia
# Tomek Garstka
# Tomek i Aga
# Tomek, Maja, Nikodem i 2 innych użytkowników
# Tomek, Mikołaj, Krzysztof i Michał
# Tomek, Mikołaj, Lena i 2 innych użytkowników
# Tomek Mycielski
# To Nie Ja
# tooo late
# Trójki Klasowe 2021/22
# Trójki Klasowe 8LO
# Trójki Klasowe Ósemki
# Truskaweczki
# TVPW
# Twd
# Tymek Barciński
# Tymoteusz Borsiak
# Tymoteusz Kwieciński
# Tymoteusz Urban
# ✨ Urodziny Marty ✨
# Vertez Hub
# Viktoriia Kyryk
# Wanda Lisiecka
# Warsztaty Klub VIII
# 💛🦋
# Ważne WRS MiNI 2022
# Ważne WRS MiNI 2023
# Weronika Arciuch
# Weronika Bąk
# Weronika Bielecka
# Weronika Januszewska
# Weronika Komuda
# Weronika Skowrońska
# Wiec
# Wieslawa Wolniak
# wigilia MiNI
# wigilia na zadupiu
# Wiktoriaa Skowera
# Wiktoria Bańka
# Wiktoria Borys
# Wiktoria Figiel
# Wiktoria Golon
# Wiktoria Kata
# Wiktoria Koładkiewicz
# Wiktoria Kowalczyk
# Wiktor i Alan
# Wiktoria Małek
# Wiktoria Parecka
# Wiktoria Przybył
# Wiktoria Wojciechowska
# Wiktor i Zosia
# Wiktor Janikowski
# Wiktor Lisiecki
# Wiktor, Wanda i Zosia
# Wiktor Wierzchowski
# Wiktor, Wiktoria, Patrycja i Agata
# Wiktor Woźniak
# Wiktor Zagawa
# Wiktor, Zosia i Sandra
#
# Wlotki Na Backyard
# Wojciech Gunia
# Wojciech Janicki
# Wojciech Łukaszek
# Wojciech Zysnarski
# Wojtek Basiński
# Wojtek Grabias
# Wojtek Karol Klimecki
# Wojtek Krajewski
# Wojtek Michaluk
# WOK Boże
# WoK - Socrealizm
# Wolontariat 8 LO
# WooHoo Sims
# Wos
# wycieczka
# wycieczka
# Wydawnictwo Aksjomat Toruń
# Wyjazd Do Auschwitz
# Wyjazd Katyń
#
# Zack Gre-Cze
# Zacny suchar milordzie.
# Zdjęcia z wędrówki
# zdjęcie z podkowa
# Zofia Gorzkowska
# Zosia Borowczyk
# Zosia Boruta
# Zosia Gramsz
# Zosia Gronowska
# Zosia i Sandra
# Zosia Łągiewka
# Zosia Olender
# Zosia Pietrasik
# Zosia Rajek
# Zu Garrard
# Zuza Gawrońska
# Zuza Makowska
# Zuzanna Borucka
# Zuzanna Piosik
# Zuzanna Piróg
# Zuzanna Pszczółka
# Zuzanna Schiller
# Zuzanna Schur
# Zuza Rybacka

# %%
#df['date'] = pd.to_datetime(df.timestamp_ms, unit='ms') <- linijka która zamienia ten dziwny czas timestamp na normlaną datę
merged_message.to_csv(me + '_'+ 'merged_message.csv')
merged_common_words.to_csv(me + '_'+ 'merged_common_words.csv')
merged_time.to_csv(me + '_'+ 'merged_time.csv')

# %%
# Out:
#                            date                 file
# 0    2022-12-06 09:26:13.503000  Agnieszka Grabarska
# 2    2022-12-06 09:20:13.788000  Agnieszka Grabarska
# 3    2022-12-06 06:40:18.386000  Agnieszka Grabarska
# 7    2022-12-04 20:55:44.016000  Agnieszka Grabarska
# 9    2022-12-04 20:44:24.122000  Agnieszka Grabarska
# ..                          ...                  ...
# 125  2020-11-19 13:58:17.789000         Zuza Rybacka
# 126  2020-11-19 13:58:15.844000         Zuza Rybacka
# 129  2020-11-19 13:57:39.465000         Zuza Rybacka
# 130  2020-11-19 13:56:05.094000         Zuza Rybacka
# 131  2020-11-19 13:55:22.634000         Zuza Rybacka
#
# [387296 rows x 2 columns]

# %%
# Out:
#            word  count                 file
# 0      dobranoc   84.0  Agnieszka Grabarska
# 1        kocham   42.0  Agnieszka Grabarska
# 2         chyba   38.0  Agnieszka Grabarska
# 3             😂   33.0  Agnieszka Grabarska
# 4            ok   31.0  Agnieszka Grabarska
# ..          ...    ...                  ...
# 189  konkretnie    1.0         Zuza Rybacka
# 190       kupił    1.0         Zuza Rybacka
# 191    niedługo    1.0         Zuza Rybacka
# 192  informacja    1.0         Zuza Rybacka
# 193   potrzebna    1.0         Zuza Rybacka
#
# [561099 rows x 3 columns]
